# %%
#imports
import pandas as pd
dado = pd.read_csv('salaries_by_college_major.csv')

# %%
#visualizando o número de linhas e colunas
dado.shape
# Out:
# (51, 6)

# %%
#visualizando todas as colunas e linhas do dado
dado
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
#verificar se tem dados inuteis ou faltantes
dado.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
#metodo responsável por encontrar as últimas linhas do dado. Que por acaso mostra que a última linha apresenta valores NaN
dado.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
#metodo responsável por retirar as linhas com valores NaN
clean_dado = dado.dropna()
clean_dado.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
#acessando as linhas de uma coluna especifica
clean_dado['Undergraduate Major']
# Out:
# 0                               Accounting
# 1                    Aerospace Engineering
# 2                              Agriculture
# 3                             Anthropology
# 4                             Architecture
# 5                              Art History
# 6                                  Biology
# 7                      Business Management
# 8                     Chemical Engineering
# 9                                Chemistry
# 10                       Civil Engineering
# 11                          Communications
# 12                    Computer Engineering
# 13                        Computer Science
# 14                            Construction
# 15                        Criminal Justice
# 16                                   Drama
# 17                               Economics
# 18                               Education
# 19                  Electrical Engineering
# 20                                 English
# 21                                    Film
# ...

# %%
#retorna o maior valor da coluna 'Starting Median Salary'
clean_dado['Starting Median Salary'].max()
# Out:
# 74300.0

# %%
#retorna o indice da linha de maior valor
clean_dado['Starting Median Salary'].idxmax()
# Out:
# 43

# %%
#para localizar o nome da graduação com maior valor de acordo com o indice
clean_dado['Undergraduate Major'].loc[43]
# Out:
# 'Physician Assistant'

# %%
#para puxar todas as linhas e colunas do indice
clean_dado.loc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %%
#baseado na questão: What college major has the highest mid-career salary? How much do graduates with this major earn? (Mid-career is defined as having 10+ years of experience).
clean_dado['Mid-Career 10th Percentile Salary'].max()
# Out:
# 71900.0

# %%
clean_dado['Mid-Career 10th Percentile Salary'].idxmax()
# Out:
# 8

# %%
clean_dado.loc[8]
# Out:
# Undergraduate Major                  Chemical Engineering
# Starting Median Salary                            63200.0
# Mid-Career Median Salary                         107000.0
# Mid-Career 10th Percentile Salary                 71900.0
# Mid-Career 90th Percentile Salary                194000.0
# Group                                                STEM
# Name: 8, dtype: object

# %%
#baseado na questão: Which college major has the lowest starting salary and how much do graduates earn after university?
clean_dado['Starting Median Salary'].min()
# Out:
# 34000.0

# %%
clean_dado['Starting Median Salary'].idxmin()
# Out:
# 49

# %%
clean_dado.loc[49]
# Out:
# Undergraduate Major                  Spanish
# Starting Median Salary               34000.0
# Mid-Career Median Salary             53100.0
# Mid-Career 10th Percentile Salary    31000.0
# Mid-Career 90th Percentile Salary    96400.0
# Group                                   HASS
# Name: 49, dtype: object

# %%
#baseado na questão: Which college major has the lowest mid-career salary and how much can people expect to earn with this degree?
clean_dado['Mid-Career Median Salary'].min()
# Out:
# 52000.0

# %%
clean_dado['Mid-Career Median Salary'].idxmin()
# Out:
# 18

# %%
clean_dado.loc[18]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary                 34900.0
# Mid-Career Median Salary               52000.0
# Mid-Career 10th Percentile Salary      29300.0
# Mid-Career 90th Percentile Salary     102000.0
# Group                                     HASS
# Name: 18, dtype: object

# %%
#calcular e visualizar o spread do 90th salario do 10th salario
spread_col = clean_dado['Mid-Career 90th Percentile Salary'] - clean_dado['Mid-Career 10th Percentile Salary']
clean_dado.insert(1, 'Spread', spread_col)
clean_dado.head()
# Out:
#      Undergraduate Major    Spread  Starting Median Salary  \
# 0             Accounting  109800.0                 46000.0
# 1  Aerospace Engineering   96700.0                 57700.0
# 2            Agriculture  113700.0                 42600.0
# 3           Anthropology  104200.0                 36800.0
# 4           Architecture   85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# ...

# %%
#os 5 mais baixos Spreads
low_spread = clean_dado.sort_values('Spread')
low_spread[['Undergraduate Major', 'Spread']].head()
# Out:
#            Undergraduate Major   Spread
# 40                     Nursing  50700.0
# 43         Physician Assistant  57600.0
# 41                   Nutrition  65300.0
# 49                     Spanish  65400.0
# 27  Health Care Administration  66400.0

# %%
#baseado na questão: Using the .sort_values() method, can you find the degrees with the highest potential? Find the top 5 degrees with the highest values in the 90th percentile.
high_potential = clean_dado.sort_values('Mid-Career 90th Percentile Salary', ascending=False)
high_potential[['Undergraduate Major', 'Mid-Career 90th Percentile Salary']].head()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 17             Economics                           210000.0
# 22               Finance                           195000.0
# 8   Chemical Engineering                           194000.0
# 37                  Math                           183000.0
# 44               Physics                           178000.0

# %%
#encontrar os 5 maiores Spreads
high_spread = clean_dado.sort_values('Spread', ascending=False)
high_spread[['Undergraduate Major', 'Spread']].head()
# Out:
#    Undergraduate Major    Spread
# 17           Economics  159400.0
# 22             Finance  147800.0
# 37                Math  137800.0
# 36           Marketing  132900.0
# 42          Philosophy  132500.0

# %%
#encontrar as maiores diferenças salariais do inicio da carreira até o meio tempo de carreira
diference_salary = clean_dado['Mid-Career Median Salary'] - clean_dado['Starting Median Salary']
clean_dado.insert(1,'Diference Salary Between Starting and Mid', diference_salary)
clean_dado.head()
# Out:
#      Undergraduate Major  Diference Salary Between Starting and Mid    Spread  \
# 0             Accounting                                    31100.0  109800.0
# 1  Aerospace Engineering                                    43300.0   96700.0
# 2            Agriculture                                    29300.0  113700.0
# 3           Anthropology                                    24700.0  104200.0
# 4           Architecture                                    35200.0   85400.0
#
#    Starting Median Salary  Mid-Career Median Salary  \
# 0                 46000.0                   77100.0
# 1                 57700.0                  101000.0
# 2                 42600.0                   71900.0
# 3                 36800.0                   61500.0
# 4                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# ...

# %%
high_salary = clean_dado.sort_values('Diference Salary Between Starting and Mid', ascending=False)
high_salary[['Undergraduate Major', 'Diference Salary Between Starting and Mid']].head()
# Out:
#      Undergraduate Major  Diference Salary Between Starting and Mid
# 17             Economics                                    48500.0
# 44               Physics                                    47000.0
# 37                  Math                                    47000.0
# 8   Chemical Engineering                                    43800.0
# 12  Computer Engineering                                    43600.0
